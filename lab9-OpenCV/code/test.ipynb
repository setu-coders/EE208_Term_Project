# %%
import cv2
from matplotlib import pyplot as plt
img_bgr = cv2.imread('images/img1.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()
plt.plot([1,2,3,4], [1,4,9,16])
plt.savefig('chart.png')
